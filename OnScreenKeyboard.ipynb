# %%
# widgets  - are the labels, buttons, and the frames we use on our window
# * - means importing all classes 
# and methods of the entire tkinter module
from tkinter import *
# as td means td can used instead of typing all the ttkthemes 
# on later lines
import ttkthemes as td 
from tkinter import ttk

# define a function named choose passing a parameter
# mouse click (click) paramter is passed 

def choose(click):
# assigning the widget being selected to a currentWidget variable(Button) 
    currentWidget = click.widget
    widgetValue = currentWidget["text"]
    
    
    if widgetValue == "Space":
        textArea.insert(INSERT, " ")
    
    
    elif widgetValue == "Enter":
        textArea.insert(INSERT, "\n")
   

    elif widgetValue == "Tab":
        textArea.insert(INSERT, "\t")
    
    # if Del is selected the entire text is delted
    # 0.0 - END describes the index, which is the whole 
    # text in this case
    elif widgetValue == "Del":
        textArea.delete(0.0, END)
        
    elif widgetValue == "Backs":
        # copy what is in current text area into a variable
        # for example, Getaante\n comes with the slash n 
        # It's why we have -2 at the end, to include '\' & "n"
        currentTextArea = textArea.get(0.0,END)
        newTextArea = currentTextArea[:-2]
        
        # since the newTextArea has a duplicate
        # the exisiting text needs to be deleted first
        
        textArea.delete(0.0,END)
        
        # insert the deleted (modified character) into newTextArea section
        textArea.insert(INSERT,newTextArea) 
    
    
    elif widgetValue == "Caps": 
        # when Caps is clicked the small Caps will disappear and
        # the Capital CAPS appears 
        buttonCaps.grid_remove()
        
        buttonCAPS.grid()
        
        # This updates the small letter into a Capital letter
        buttonQ.config(text="Q")
        
        buttonW.config(text="W")
        
        buttonE.config(text="E")
        
        buttonR.config(text="R")
        
        buttonT.config(text="T")
        
        buttonY.config(text="Y")
        
        buttonU.config(text="U")
        
        buttonI.config(text="I")
        
        buttonO.config(text="O")
        
        buttonP.config(text="P")
        
        buttonA.config(text="A")
        
        buttonS.config(text="S")
        
        buttonD.config(text="D")
        
        buttonF.config(text="F")
        
        buttonG.config(text="G") 
        
        buttonH.config(text="H")
        
        buttonJ.config(text="J")
        
        buttonK.config(text="K")
        
        buttonL.config(text="L")
        
        buttonZ.config(text="Z")
        
        buttonX.config(text="X")
        
        buttonC.config(text="C")
        
        buttonV.config(text="V")
        
        buttonB.config(text="B")
        
        buttonN.config(text="N")
        
        buttonM.config(text="M")
        
        
    elif widgetValue == "CAPS":
        
        # when CAPS is clicked the Capital CAPS will disappear and
        # the small Caps appears 
        buttonCAPS.grid_remove()
        
        buttonCaps.grid()
        
         # This updates the Capital letter into a Small letter
        buttonQ.config(text="q")
        
        buttonW.config(text="w")
        
        buttonE.config(text="e")
        
        buttonR.config(text="r")
        
        buttonT.config(text="t")
        
        buttonY.config(text="y")
        
        buttonU.config(text="u")
        
        buttonI.config(text="i")
        
        buttonO.config(text="o")
        
        buttonP.config(text="p")
        
        buttonA.config(text="a")
        
        buttonS.config(text="s")
        
        buttonD.config(text="d")
        
        buttonF.config(text="f")
        
        buttonG.config(text="g") 
        
        buttonH.config(text="h")
        
        buttonJ.config(text="j")
        
        buttonK.config(text="k")
        
        buttonL.config(text="l")
        
        buttonZ.config(text="z")
        
        buttonX.config(text="x")
        
        buttonC.config(text="c")
        
        buttonV.config(text="v")
        
        buttonB.config(text="b")
        
        buttonN.config(text="n")
        
        buttonM.config(text="m")
    # if keys other than CAPS and Backs clicked,
    # the text of the selected button will be
    # displayed on the textArea
    else:
        textArea.insert(INSERT,widgetValue)
        
        
def shift():
    
    apostropheButton.grid_remove()
    
    button1.grid_remove()
    
    button2.grid_remove()
        
    button3.grid_remove()   

    button4.grid_remove()
    
    button5.grid_remove()
    
    button6.grid_remove()
    
    button7.grid_remove()
    
    button8.grid_remove()
    
    button9.grid_remove()
    
    buttonDash.grid_remove()
    
    buttonEquals.grid_remove()
    
    buttonRightBracket.grid_remove()
    
    buttonSemicolon.grid_remove()

    buttonComma.grid_remove()
    
    buttonForwardSlash.grid_remove()
    
    buttonPeriod.grid_remove()
    
    
    
    
    tildeButton.grid()
    
    buttonExclamation.grid()
    
    buttonAt.grid()
    
    buttonHash.grid()
    
    buttonDollar.grid()
    
    buttonPercent.grid()
    
    buttonExponent.grid()
    
    buttonAmpersand.grid()
    
    buttonAsterisk.grid()
    
    buttonLeftParenthesis.grid()
    
    buttonLeftBracket.grid()
    
    buttonRightParenthesis.grid()
   
    buttonAddition.grid()
    
    buttonColon.grid()
    
    buttonGreaterThan.grid()
    
    buttonLessThan.grid()

    buttonQuestion.grid()
    
    buttonUnderscore.grid()
    
    buttonLeftBracket.grid()
    
    
def shiftA():
    
    tildeButton.grid_remove()
    
    buttonExclamation.grid_remove()
    
    buttonAt.grid_remove()
    
    buttonHash.grid_remove()
    
    buttonDollar.grid_remove()
    
    buttonPercent.grid_remove()
    
    buttonExponent.grid_remove()
    
    buttonAmpersand.grid_remove()
    
    buttonAsterisk.grid_remove()
    
    buttonLeftParenthesis.grid()
    
    buttonRightParenthesis.grid()
   
    buttonAddition.grid_remove()
    
    buttonColon.grid_remove()
    
    buttonGreaterThan.grid_remove()
    
    buttonLessThan.grid_remove()

    buttonQuestion.grid_remove()
    
    buttonUnderscore.grid_remove()
    
    buttonLeftBracket.grid_remove()
    
    
    
    
    apostropheButton.grid()
    
    button1.grid()
    
    button2.grid()
        
    button3.grid()   

    button4.grid()
    
    button5.grid()
    
    button6.grid()
    
    button7.grid()
    
    button8.grid()
    
    button9.grid()
    
    buttonDash.grid()
    
    buttonEquals.grid()
    
    buttonRightBracket.grid()
    
    buttonSemicolon.grid()

    buttonComma.grid()
    
    buttonForwardSlash.grid()
        
    buttonPeriod.grid()
    
    
        
# create an instance of a td.theemedTK(themed version of tkinter)class
# window is created, but not displayed yet
root = td.ThemedTk()

root.get_themes()

# sets the type of themes in this pariticular case radiance is used
root.set_theme('clearlooks')

root.title('Start Up Keyboard')

root.config(bg='gray30')
root.resizable(False,False)

# Instantiate Label class
# fg -> text color, bg -> background color 
titleLabel = Label(root,text="Keyboard",font=("arial",20,"bold"),fg="brown",bg = "gray30")

# sets the size of the label created 
titleLabel.grid(row=0,columnspan = 40)

# create an instance of Text class
# specify which window should the text run root in this case
# word = "wrap" allows the a last word to go to a new line. 
textArea = Text(root, font = ('arial',15,'bold'),height = 10,width = 100,wrap='word')
textArea.grid(row=1,columnspan=40)

# focuses the cursor when ever the application is running
textArea.focus_set()

# instantiate a frame class 
# the frame is under root window 
keysFrame = Frame(root,bg="whitesmoke")
# helps us to place the frame inside our window with the given measurenments
keysFrame.grid(row=2)

# inorder to use the ttk themes class we instantiate it here first
# instantiate a button class
# since we want the button to be under frame object, we will pass it as an argument
apostropheButton = ttk.Button(keysFrame,text="`",width=5)
# places the button inside the frame 
apostropheButton.grid(row=0,column=0)

tildeButton=ttk.Button(keysFrame,text="~",width=5)
#places the button in the given location inside the frame object created
tildeButton.grid(row=0,column=0)
#removes the tilden button created inorder to show the aposthrophe first
tildeButton.grid_remove()

button1= ttk.Button(keysFrame,text='1',width=5)
button1.grid(row=0,column=1)

buttonExclamation = ttk.Button(keysFrame,text="!",width=5)
buttonExclamation.grid(row=0,column=1)
buttonExclamation.grid_remove()

button2 = ttk.Button(keysFrame,text="2",width=5)
button2.grid(row=0,column=2)

buttonAt = ttk.Button(keysFrame,text="@",width=5)
buttonAt.grid(row=0,column=2)
buttonAt.grid_remove()


button3 = ttk.Button(keysFrame,text="3",width=5)
button3.grid(row=0,column=3)


buttonHash = ttk.Button(keysFrame,text="#",width=5)
buttonHash.grid(row=0,column=3)
buttonHash.grid_remove()


button4 = ttk.Button(keysFrame,text="4",width=5)
button4.grid(row=0,column=4)


buttonDollar = ttk.Button(keysFrame,text="$",width=5)
buttonDollar.grid(row=0,column=4)
buttonDollar.grid_remove()


button5 = ttk.Button(keysFrame,text="5",width=5)
button5.grid(row=0,column=5)


buttonPercent = ttk.Button(keysFrame,text="%",width=5)
buttonPercent.grid(row=0,column=5)
buttonPercent.grid_remove()


button6 = ttk.Button(keysFrame,text="6",width=5)
button6.grid(row=0,column=6)


buttonExponent = ttk.Button(keysFrame,text="^",width=5)
buttonExponent.grid(row=0,column=6)
buttonExponent.grid_remove()


button7 = ttk.Button(keysFrame,text="7",width=5)
button7.grid(row=0,column=7)


buttonAmpersand = ttk.Button(keysFrame,text="&",width=5)
buttonAmpersand.grid(row=0,column=7)
buttonAmpersand.grid_remove()


button8 = ttk.Button(keysFrame,text="8",width=5)
button8.grid(row=0,column=8)


buttonAsterisk = ttk.Button(keysFrame,text="*",width=5)
buttonAsterisk.grid(row=0,column=8)
buttonAsterisk.grid_remove()


button9 = ttk.Button(keysFrame,text="9",width=5)
button9.grid(row=0,column=9)


buttonLeftParenthesis = ttk.Button(keysFrame,text="(",width=5)
buttonLeftParenthesis.grid(row=0,column=9)
buttonLeftParenthesis.grid_remove()


button0 = ttk.Button(keysFrame,text="0",width=5)
button0.grid(row=0,column=10)


buttonRightParenthesis = ttk.Button(keysFrame,text=")",width=5)
buttonRightParenthesis.grid(row=0,column=10)
buttonRightParenthesis.grid_remove()


buttonDash = ttk.Button(keysFrame,text="-",width=5)
buttonDash.grid(row=0,column=11)


buttonUnderscore = ttk.Button(keysFrame,text="_",width=5)
buttonUnderscore.grid(row=0,column=11)
buttonUnderscore.grid_remove()


buttonEquals = ttk.Button(keysFrame,text="=",width=5)
buttonEquals.grid(row=0,column=12)


buttonAddition = ttk.Button(keysFrame,text="+",width=5)
buttonAddition.grid(row=0,column=12)
buttonAddition.grid_remove()


buttonBacks = ttk.Button(keysFrame,text="Backs",width=5)
buttonBacks.grid(row=0,column=13)


buttonDelete = ttk.Button(keysFrame,text="Del",width=5)
buttonDelete.grid(row=0,column=14)


buttonTab = ttk.Button(keysFrame,text="Tab",width=5)
buttonTab.grid(row=1,column=0)


buttonQ = ttk.Button(keysFrame,text="q",width=5)
buttonQ.grid(row=1,column=1)


buttonW = ttk.Button(keysFrame,text="w",width=5)
buttonW.grid(row=1,column=2)

buttonE = ttk.Button(keysFrame,text="e",width=5)
buttonE.grid(row=1,column=3)

buttonR = ttk.Button(keysFrame,text="r",width=5)
buttonR.grid(row=1,column=4)

buttonT = ttk.Button(keysFrame,text="t",width=5)
buttonT.grid(row=1,column=5)

buttonY = ttk.Button(keysFrame,text="y",width=5)
buttonY.grid(row=1,column=6)

buttonU = ttk.Button(keysFrame,text="u",width=5)
buttonU.grid(row=1,column=7)

buttonI = ttk.Button(keysFrame,text="i",width=5)
buttonI.grid(row=1,column=8)

buttonO = ttk.Button(keysFrame,text="o",width=5)
buttonO.grid(row=1,column=9)


buttonP = ttk.Button(keysFrame,text="p",width=5)
buttonP.grid(row=1,column=10)


buttonLeftBracket = ttk.Button(keysFrame,text="[",width=5)
buttonLeftBracket.grid(row=1,column=11)


buttonRightBracket = ttk.Button(keysFrame,text="]",width=5)
buttonRightBracket.grid(row=1,column=11)
buttonRightBracket.grid_remove()


buttonSeven = ttk.Button(keysFrame,text="7",width=5)
buttonSeven.grid(row=1,column=12)


buttonEight = ttk.Button(keysFrame,text="8",width=5)
buttonEight.grid(row=1,column=13)


buttonNine = ttk.Button(keysFrame,text="9",width=5)
buttonNine.grid(row=1,column=14)

buttonCaps = ttk.Button(keysFrame,text="Caps",width=5)
buttonCaps.grid(row=2,column=0)


buttonCAPS = ttk.Button(keysFrame,text="CAPS",width=5)
buttonCAPS.grid(row=2,column=0)
buttonCAPS.grid_remove()


buttonA = ttk.Button(keysFrame,text="a",width=5)
buttonA.grid(row=2,column=1)


buttonS = ttk.Button(keysFrame,text="s",width=5)
buttonS.grid(row=2,column=2)


buttonD = ttk.Button(keysFrame,text="d",width=5)
buttonD.grid(row=2,column=3)


buttonF = ttk.Button(keysFrame,text="f",width=5)
buttonF.grid(row=2,column=4)


buttonG = ttk.Button(keysFrame,text="g",width=5)
buttonG.grid(row=2,column=5)


buttonH = ttk.Button(keysFrame,text="h",width=5)
buttonH.grid(row=2,column=6)


buttonJ = ttk.Button(keysFrame,text="j",width=5)
buttonJ.grid(row=2,column=7)


buttonK = ttk.Button(keysFrame,text="k",width=5)
buttonK.grid(row=2,column=8)


buttonL = ttk.Button(keysFrame,text="l",width=5)
buttonL.grid(row=2,column=9)


buttonSemicolon = ttk.Button(keysFrame,text=";",width=5)
buttonSemicolon.grid(row=2,column=10)


buttonColon = ttk.Button(keysFrame,text=":",width=5)
buttonColon.grid(row=2,column=10)
buttonColon.grid_remove()


buttonEnter = ttk.Button(keysFrame,text="Enter",width=5)
buttonEnter.grid(row=2,column=11)


buttonFour = ttk.Button(keysFrame,text="4",width=5)
buttonFour.grid(row=2,column=12)


buttonFive = ttk.Button(keysFrame,text="5",width=5)
buttonFive.grid(row=2,column=13)


buttonSix = ttk.Button(keysFrame,text="6",width=5)
buttonSix.grid(row=2,column=14)

# # command paramter invokes a function when "buttonShift is selected"
buttonShift = ttk.Button(keysFrame,text="Shift",width=5,command=shift)
buttonShift.grid(row=3,column=0)


buttonZ = ttk.Button(keysFrame,text="z",width=5)
buttonZ.grid(row=3,column=1)


buttonX = ttk.Button(keysFrame,text="x",width=5)
buttonX.grid(row=3,column=2)


buttonC = ttk.Button(keysFrame,text="c",width=5)
buttonC.grid(row=3,column=3)


buttonV = ttk.Button(keysFrame,text="v",width=5)
buttonV.grid(row=3,column=4)


buttonB = ttk.Button(keysFrame,text="b",width=5)
buttonB.grid(row=3,column=5)

buttonN = ttk.Button(keysFrame,text="n",width=5)
buttonN.grid(row=3,column=6)


buttonM = ttk.Button(keysFrame,text="m",width=5)
buttonM.grid(row=3,column=7)


buttonComma = ttk.Button(keysFrame,text=",",width=5)
buttonComma.grid(row=3,column=8)


buttonLessThan = ttk.Button(keysFrame,text="<",width=5)
buttonLessThan.grid(row=3,column=8)
buttonLessThan.grid_remove()


buttonPeriod = ttk.Button(keysFrame,text=".",width=5)
buttonPeriod.grid(row=3,column=9)


buttonGreaterThan = ttk.Button(keysFrame,text=">",width=5)
buttonGreaterThan.grid(row=3,column=9)
buttonGreaterThan.grid_remove()


buttonForwardSlash = ttk.Button(keysFrame,text="/",width=5)
buttonForwardSlash.grid(row=3,column=10)


buttonQuestion = ttk.Button(keysFrame,text="?",width=5)
buttonQuestion.grid(row=3,column=10)
buttonQuestion.grid_remove()

# command paramter invokes a function when "buttonShift is called"
buttonShift = ttk.Button(keysFrame,text="Shift",width=5,command=shiftA)
buttonShift.grid(row=3,column=11)


buttonOne = ttk.Button(keysFrame,text="1",width=5)
buttonOne.grid(row=3,column=12)


buttonTwo = ttk.Button(keysFrame,text="2",width=5)
buttonTwo.grid(row=3,column=13)


buttonThree = ttk.Button(keysFrame,text="3",width=5)
buttonThree.grid(row=3,column=14)


buttonSpaceBar = ttk.Button(keysFrame,text="Space",width=30)
buttonSpaceBar.grid(row=4,column=0,columnspan=40)


# the bind function gives functionality for given button
# Button-1 represents the left click
# when left mouse is clicked the choose function is invoked


button1.bind('<Button-1>', choose)

button2.bind('<Button-1>', choose)

button3.bind('<Button-1>', choose)

button4.bind('<Button-1>', choose)

button5.bind('<Button-1>', choose)

button6.bind('<Button-1>', choose)

button7.bind('<Button-1>', choose)

button8.bind('<Button-1>', choose)

button9.bind('<Button-1>', choose)

button0.bind('<Button-1>', choose)

apostropheButton.bind('<Button-1>', choose)

tildeButton.bind('<Button-1>', choose)

buttonDash.bind('<Button-1>', choose)

buttonDash.bind('<Button-1>', choose)

buttonEquals.bind('<Button-1>', choose)

buttonBacks.bind('<Button-1>', choose)

buttonDelete.bind('<Button-1>', choose)

buttonQ.bind('<Button-1>', choose)

buttonW.bind('<Button-1>', choose)

buttonE.bind('<Button-1>', choose)

buttonR.bind('<Button-1>', choose)

buttonT.bind('<Button-1>', choose)

buttonY.bind('<Button-1>', choose)

buttonU.bind('<Button-1>', choose)

buttonI.bind('<Button-1>', choose)

buttonO.bind('<Button-1>', choose)

buttonP.bind('<Button-1>', choose)

buttonA.bind('<Button-1>', choose)

buttonS.bind('<Button-1>', choose)

buttonD.bind('<Button-1>', choose)

buttonF.bind('<Button-1>', choose)

buttonG.bind('<Button-1>', choose)

buttonH.bind('<Button-1>', choose)

buttonJ.bind('<Button-1>', choose)

buttonK.bind('<Button-1>', choose)

buttonL.bind('<Button-1>', choose)

buttonZ.bind('<Button-1>', choose)

buttonX.bind('<Button-1>', choose)

buttonC.bind('<Button-1>', choose)

buttonV.bind('<Button-1>', choose)

buttonB.bind('<Button-1>', choose)

buttonN.bind('<Button-1>', choose)

buttonM.bind('<Button-1>', choose)

buttonColon.bind('<Button-1>', choose)

buttonComma.bind('<Button-1>', choose)

buttonForwardSlash.bind('<Button-1>', choose)

buttonCaps.bind('<Button-1>', choose)

buttonCAPS.bind('<Button-1>', choose)

buttonOne.bind('<Button-1>', choose)

buttonTwo.bind('<Button-1>', choose)

buttonThree.bind('<Button-1>', choose)

buttonFour.bind('<Button-1>', choose)

buttonFive.bind('<Button-1>', choose)

buttonSix.bind('<Button-1>', choose)

buttonSeven.bind('<Button-1>', choose)

buttonEight.bind('<Button-1>', choose)

buttonNine.bind('<Button-1>', choose)

buttonSpaceBar.bind('<Button-1>',choose)

buttonEquals.bind('<Button-1>',choose)

buttonLeftBracket.bind('<Button-1>',choose)

buttonRightBracket.bind('<Button-1>',choose)

buttonTab.bind('<Button-1>',choose)

buttonPeriod.bind('<Button-1>',choose)

buttonExclamation.bind('<Button-1>',choose)

buttonAt.bind('<Button-1>',choose)

buttonHash.bind('<Button-1>',choose)

buttonDollar.bind('<Button-1>',choose)

buttonPercent.bind('<Button-1>',choose)

buttonExponent.bind('<Button-1>',choose)

buttonAmpersand.bind('<Button-1>',choose)

buttonAsterisk.bind('<Button-1>',choose)

buttonLeftParenthesis.bind('<Button-1>',choose)

buttonRightParenthesis.bind('<Button-1>',choose)

buttonUnderscore.bind('<Button-1>',choose)

buttonAddition.bind('<Button-1>',choose)

buttonSemicolon.bind('<Button-1>',choose)

buttonLessThan.bind('<Button-1>',choose)

buttonGreaterThan.bind('<Button-1>',choose)

buttonQuestion.bind('<Button-1>',choose)




# a method of the TK class and it helps to hold 
# the created window (it makes it not disappear)
root.mainloop()
